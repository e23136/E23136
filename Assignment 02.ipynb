# %% [markdown]
# <a href="https://colab.research.google.com/github/e23136/E23136/blob/main/Assignment%2002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Question 03
#
#  1.
#  Sample Space ($\Omega$): $\{0, 1, 2, 3\}$<br><br>
#  Probability Measure ($P$):<br>
#  $P(\{0\}) = 0.50$<br>$P(\{1\}) = 0.30$<br>$P(\{2\}) = 0.15$<br>$P(\{3\}) = 0.05$<br><br>
#
#  2.
#  $X(\omega) = \omega$<br><br>
#
#
#  3.
#  Probability Mass Function (PMF):<br>
# $$p_X(x) = P(X = x) = \begin{cases} 0.50, & x=0 \\ 0.30, & x=1 \\ 0.15, & x=2 \\ 0.05, & x=3 \\ 0, & \text{otherwise} \end{cases}$$<br><br>
#
# 4.
# $$E[X] = (0 \times 0.50) + (1 \times 0.30) + (2 \times 0.15) + (3 \times 0.05)$$<br>
# $$E[X] = 0 + 0.30 + 0.30 + 0.15 = \mathbf{0.75}$$<br><br>
#
#
#
# 5.
# $$E[X^2] = (0^2 \times 0.50) + (1^2 \times 0.30) + (2^2 \times 0.15) + (3^2 \times 0.05)$$<br>
# $$E[X^2] = 0 + 0.30 + 0.60 + 0.45 = 1.35$$<br><br>
#
#
# 6.
# $P(X \geq 1)$: $$0.30 + 0.15 + 0.05 = \mathbf{0.50}$$<br>
# $P(X \geq 2)$: $$0.15 + 0.05 = \mathbf{0.20}$$
# <br><br>
#
#
# 7.
# Expectation (0.75): an average of 0.75 failures per day.<br><br>
# Variance (0.7875): This tells us how much the daily count fluctuates. Since the variance is relatively small, most days will stay close to the average (mostly 0 or 1 failures), and seeing 3 failures is very rare.
# <br><br>

# %% [markdown]
# # Question 04
#
# 1.
# Probability Space: $\Omega_1 = [0, \pi]$<br><br>
# where, $$P(A) = \int_{A} f(x) \, dx, \quad A \in \mathfrak{F},$$
# <br><br>
#
# 2.
# $X(\omega) = \omega$  for $\omega \in [0, 1]$
# <br><br>
#
#
# 3.
# Probability Density Function (PDF):<br><br>
# Given $\alpha = 2$ and $\beta = 18$, the PDF of $X$ is:$$f(x) = \begin{cases} \frac{1}{B(2, 18)} x^1 (1-x)^{17} & \text{if } 0 < x < 1 \\ 0 & \text{otherwise} \end{cases}$$
# <br><br>
#
#
# 4.
# $f(x) \geq 0$ for all $x$, which is true since $x$ and $(1-x)$ are positive on $(0, 1)$<br><br>
# Total Area: The integral over all space must equal 1:$$\int_{0}^{1} \frac{1}{B(2, 18)} x^{2-1} (1-x)^{18-1} \, dx = \frac{B(2, 18)}{B(2, 18)} = 1$$
# <br><br>
#
#
#
# 5.
# For a Beta distribution:<br>
#  mean = $\frac{\alpha}{\alpha + \beta}$:$$E[X] = \frac{2}{2 + 18} = \frac{2}{20} = \mathbf{0.10}$$
# <br><br>
#
#
# 6.
# $$\text{Var}(X) = \frac{(2)(18)}{(20)^2(21)} = \frac{36}{8400} = \frac{3}{700} \approx \mathbf{0.00429}$$
# <br><br>
#
#
#
# 7.
# The area under the curve from 0 to 0.10:<br><br>
# $$P(X \leq 0.10) = \int_{0}^{0.10} \frac{1}{B(2, 18)} x (1-x)^{17} \, dx$$
# <br><br>
#
#
#
# 8.
# Area between 0.05 and 0.15:<br><br>
# $$P(0.05 \leq X \leq 0.15) = \int_{0.05}^{0.15} \frac{1}{B(2, 18)} x (1-x)^{17} \, dx$$
# <br><br>
#
# 9.
# The Beta distribution is a natural choice because it is strictly defined on the interval $[0, 1]$. Since a "proportion" cannot be less than 0% or more than 100%, this distribution fits the physical constraints of the problem perfectly.
# <br><br>
#
#
# 10.
# $$E[X] = 0.10$$
# <br><br>
#
# $$\text{Var}(X) \approx 0.00429$$
# <br><br>

# %% [markdown]
# # Question 05
#
#
# 1.
# Support of $X$ : $4 \leq X \leq 10$
# <br><br>
#
#
# 2.
# The Triangular distribution with $a=4$, $b=10$, and $c=6$ is defined as:<br>
#
# $$f_X(x)=\begin{cases}
# \frac{x - 4}{6} & \text{for } 4 \leq x < 6 \
# \frac{1}{3} & \text{for } x = 6 \
# \frac{10 - x}{12} & \text{for } 6 < x \leq 10 \
# 0 & \text{otherwise}
# \end{cases}$$
# <br><br>
#
#
# 3.
# Verification of the PDF:<br><br>
#
# Part 1 ($4$ to $6$):<br> $\int_{4}^{6} \frac{x-4}{6} dx = \frac{1}{6} \left[ \frac{(x-4)^2}{2} \right]_4^6 = \frac{1}{6} \cdot \frac{4}{2} = \frac{1}{3}$ <br><br>
# Part 2 ($6$ to $10$): $\int_{6}^{10} \frac{10-x}{12} dx = \frac{1}{12} \left[ -\frac{(10-x)^2}{2} \right]_6^{10} = \frac{1}{12} \cdot \frac{16}{2} = \frac{2}{3}$<br><br>
# Total: $\frac{1}{3} + \frac{2}{3} = \mathbf{1}$<br>
#  The PDF is valid.
# <br><br>
#
#
# 4.
#  Expectation $E[X]$:<br>
#
# $$E[X] = \frac{4 + 10 + 6}{3} = \frac{20}{3} \approx \mathbf{6.67 \text{ hours}}$$
# <br><br>
#
# 5.
# Variance $\text{Var}(X)$:<br>
# $\text{Var}(X) = \frac{a^2 + b^2 + c^2 - ab - ac - bc}{18}$:$$\text{Var}(X) = \frac{4^2 + 10^2 + 6^2 - (4 \cdot 10) - (4 \cdot 6) - (10 \cdot 6)}{18} = \frac{28}{18} = \frac{14}{9} \approx \mathbf{1.56}$$
# <br><br>
#
#
#
# 6.
# 6. Interpretation of Parameters<br><br>
# $a = 4$: The "best-case scenario" (shortest possible time)<br>
# $b = 10$: The "worst-case scenario" (longest possible time)<br>
# $c = 6$: The "most likely" time (the peak of the triangle).
# <br><br>
#
#
# 7.
# It is useful when you don't have a lot of historical data but have "expert opinions." By knowing only the minimum, maximum, and most likely values, you can create a logical model that is easy to understand and calculate.
# <br><br>
#
# 8.
# Probability $P(X \leq 5)$:<br>
# This is the area from 4 to 5 hours:<br><br>
# $$P(X \leq 5) = \int_{4}^{5} \frac{x-4}{6} dx = \frac{1}{6} \left[ \frac{(x-4)^2}{2} \right]_4^5 = \frac{1}{6} \cdot \frac{1}{2} = \frac{1}{12} \approx \mathbf{0.0833}$$
# <br><br>
#
#
# 9.
# Probability $P(5 \leq X \leq 8)$<br><br>
# Because it crosses the peak at $x=6$:<br><br>
# From 5 to 6:<br>
#  $\int_{5}^{6} \frac{x-4}{6} dx = \frac{1}{6} \left[ \frac{(x-4)^2}{2} \right]_5^6 = \frac{1}{6} ( \frac{4}{2} - \frac{1}{2} ) = \frac{3}{12} = \frac{1}{4}$<br><br>
#  From 6 to 8: $\int_{6}^{8} \frac{10-x}{12} dx = \frac{1}{12} \left[ -\frac{(10-x)^2}{2} \right]_6^8 = \frac{1}{12} ( \frac{16}{2} - \frac{4}{2} ) = \frac{6}{12} = \frac{1}{2}$<br><br>
#  Total: $\frac{1}{4} + \frac{1}{2} = \mathbf{0.75}$ (or 75%)
# <br><br>
#
#
# 10.
# This model helps project managers estimate risk. They can calculate the probability of missing a deadline or determine how much "buffer time" to add to a schedule. It also shows how much the final timeline might change if one of the estimates ($a, b,$ or $c$) changes.

# %% [markdown]
# # Question 06
#
#
# 1.
# Given $a = 8$, $b = 20$, and $c = 11$:<br><br>
# $\alpha$ Calculation:$$\alpha = 1 + 4\left(\frac{11 - 8}{20 - 8}\right) = 1 + 4\left(\frac{3}{12}\right) = 1 + 1 = \mathbf{2}$$$\beta$ Calculation:$$\beta = 1 + 4\left(\frac{20 - 11}{20 - 8}\right) = 1 + 4\left(\frac{9}{12}\right) = 1 + 3 = \mathbf{4}$$
# <br><br>
#
#
# 2.
# Support: $8 \leq X \leq 20$
# <br><br>
#
# 3.
# Using $\alpha = 2$ and $\beta = 4$ in the PERT formula:<br><br>
# $$f_X(x) = \frac{(x - 8)^{2-1}(20 - x)^{4-1}}{B(2, 4)(20 - 8)^{2+4-1}} = \frac{(x - 8)(20 - x)^3}{B(2, 4) \cdot 12^5}$$For $8 \leq x \leq 20$, and $0$ otherwise.
# <br><br>
# <br>
#
#
# 4.
# $\Omega$: $[8, 20]$<br><br>
# $\mathcal{F}$: The Borel $\sigma$-algebra on $[8, 20]$<br><br>
# $P$: The probability measure defined by<br>
# $P(A) = \int_{A} f_X(x) \, dx$.
# <br><br>
# <br>
#
#
# 5.
# $X(\omega) = \omega$ for $\omega \in [8, 20]$
# <br><br><br>
#
# 6.
# $$E[X] = \frac{a + 4c + b}{6} = \frac{8 + 4(11) + 20}{6} = \frac{72}{6} = \mathbf{12 \text{ days}}$$
#
# <br><br>
# <br>
#
# 7.
# $$\text{Var}(X) = \frac{(E[X] - a)(b - E[X])}{7} = \frac{(12 - 8)(20 - 12)}{7} = \frac{4 \cdot 8}{7} = \frac{32}{7} \approx \mathbf{4.57}$$
# <br><br>
#
#
# 8.
# $$\sigma = \sqrt{\frac{32}{7}} \approx \mathbf{2.14 \text{ days}}$$
# <br><br>
# <br>
#
#
#
# 9.
# The PERT distribution is often better than the Triangular distribution because, It is smoother and doesn't have a sharp "point" at the most likely value.It places more weight on the most likely value ($c$), making the mean more realistic.It usually results in a smaller variance, meaning it suggests less extreme uncertainty compared to the Triangular model
# <br><br>
# <br>
#
# 10.
# $a, b, c$: These are expert estimates for the best, worst, and most common scenarios.<br>
# $E[X] = 12$: This is the "weighted average" duration. It’s the number a manager should use for the main schedule.<br><br>
# $\sigma \approx 2.14$: This represents the risk. A higher $\sigma$ means the task is unpredictable, while a lower $\sigma$ means the manager can be more confident in the 12-day estimate.

# %% [markdown]
# # Question 07
#
#
# 1.
# PERT mean formula:$$E[X] = \frac{a + 4c + b}{6}$$
# <br><br>
#
# $$\frac{a + 4c + b}{6} = c$$
# $$a + 4c + b = 6c$$
# $$a + b = 2c$$
# $$b = 2c - a$$
# $$b = 22 - 5$$<br><br>
# $$b = \mathbf{17 \text{ days}}$$
# <br><br>
#
#
# 2.
# When $E[X] = c$, the distribution becomes symmetric<br><br>
# $$\text{Var}(X) = \frac{(E[X] - a)(b - E[X])}{7}$$
# <br><br>
# $$\text{Var}(X) = \frac{(c - a)(b - c)}{7}$$<br><br>
# Because the distribution is symmetric ($b - c = c - a$)
# $$\text{Var}(X) = \frac{(c - a)^2}{7}$$<br><br>
#
# $c=11, a=5$<br><br>
#
# $$\text{Var}(X) = \frac{(11 - 5)^2}{7} = \frac{6^2}{7} = \frac{36}{7} \approx \mathbf{5.14}$$
